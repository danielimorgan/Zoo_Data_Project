# %% [markdown]
# # Class Data Cleaning

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from pathlib import Path

# Files to Load 
class_data_load = Path("Resources/class.csv")

# Read Class Data File and store into Pandas DataFrame
class_data = pd.read_csv(class_data_load)

class_data.head()
# Out:
#    Class_Number  Number_Of_Animal_Species_In_Class Class_Type  \
# 0             1                                 41     Mammal
# 1             2                                 20       Bird
# 2             3                                  5    Reptile
# 3             4                                 13       Fish
# 4             5                                  4  Amphibian
#
#                                         Animal_Names
# 0  aardvark, antelope, bear, boar, buffalo, calf,...
# 1  chicken, crow, dove, duck, flamingo, gull, haw...
# 2    pitviper, seasnake, slowworm, tortoise, tuatara
# 3  bass, carp, catfish, chub, dogfish, haddock, h...
# 4                             frog, frog, newt, toad

# %%
# Remove one of the frogs from the list 
class_data.loc[4, 'Animal_Names'] = class_data.loc[4, 'Animal_Names'].replace('frog,', '')
class_data.loc[4, 'Animal_Names'] += ', frog, salamander'
class_data.head()
# Out:
#    Class_Number  Number_Of_Animal_Species_In_Class Class_Type  \
# 0             1                                 41     Mammal
# 1             2                                 20       Bird
# 2             3                                  5    Reptile
# 3             4                                 13       Fish
# 4             5                                  4  Amphibian
#
#                                         Animal_Names
# 0  aardvark, antelope, bear, boar, buffalo, calf,...
# 1  chicken, crow, dove, duck, flamingo, gull, haw...
# 2    pitviper, seasnake, slowworm, tortoise, tuatara
# 3  bass, carp, catfish, chub, dogfish, haddock, h...
# 4                       newt, toad, frog, salamander

# %%
# Replace Number of Animal Species in Class under mammals with 40
class_data.loc[0, 'Number_Of_Animal_Species_In_Class'] = 40

class_data.head()
# Out:
#    Class_Number  Number_Of_Animal_Species_In_Class Class_Type  \
# 0             1                                 40     Mammal
# 1             2                                 20       Bird
# 2             3                                  5    Reptile
# 3             4                                 13       Fish
# 4             5                                  4  Amphibian
#
#                                         Animal_Names
# 0  aardvark, antelope, bear, boar, buffalo, calf,...
# 1  chicken, crow, dove, duck, flamingo, gull, haw...
# 2    pitviper, seasnake, slowworm, tortoise, tuatara
# 3  bass, carp, catfish, chub, dogfish, haddock, h...
# 4                       newt, toad, frog, salamander

# %%
# Remove vampire and girl from the record and replace it with human 
class_data.loc[0, 'Animal_Names'] = class_data.loc[0, 'Animal_Names'].replace(
    'vampire,', '').replace('girl,', '') + ', human'

class_data.head()
# Out:
#    Class_Number  Number_Of_Animal_Species_In_Class Class_Type  \
# 0             1                                 40     Mammal
# 1             2                                 20       Bird
# 2             3                                  5    Reptile
# 3             4                                 13       Fish
# 4             5                                  4  Amphibian
#
#                                         Animal_Names
# 0  aardvark, antelope, bear, boar, buffalo, calf,...
# 1  chicken, crow, dove, duck, flamingo, gull, haw...
# 2    pitviper, seasnake, slowworm, tortoise, tuatara
# 3  bass, carp, catfish, chub, dogfish, haddock, h...
# 4                       newt, toad, frog, salamander

# %%
# Save the cleaned data to a file called "class_cleaned.csv".
class_data.to_csv('Clean_Data/class_cleaned.csv', index=False)
